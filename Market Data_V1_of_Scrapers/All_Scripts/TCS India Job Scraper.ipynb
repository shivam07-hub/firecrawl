# %% [markdown]
# # TCS India Job Scraper
# ## India Jobs Scraper (v2.1 - March 2026)
# **Source:** ibegin.tcs.com
#
# **ATS Detection:** Automatic API + Selenium fallback

# %%
# !pip install selenium webdriver-manager pandas openpyxl requests beautifulsoup4 lxml playwright -q
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import sys, time, random, re
from pathlib import Path

# Add scripts dir to path so we can import scraper_utils
SCRIPTS_DIR = Path.home() / "Job_Scrapers" / "All_Scripts"
sys.path.insert(0, str(SCRIPTS_DIR))

from scraper_utils import *
import requests
from bs4 import BeautifulSoup
from datetime import datetime, timedelta

print("Imports loaded. Date:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
# Out:
# scraper_utils.py loaded successfully
# Schema: 25 columns
# Skills DB: 79 skills
# Imports loaded. Date: 2026-04-01 00:55:50

# %%
COMPANY = "TCS"
OUTPUT_DIR = get_output_dir(COMPANY)
print(f"Output directory: {OUTPUT_DIR}")
# Out:
# Output directory: /Users/incognito/Job_Scrapers/All_CSV_Outputs/TCS/Outputs/2026_04_01

# %%
print("=" * 60)
print("TCS INDIA JOB SCRAPER")
print("NOTE: ibegin.tcs.com is no longer reachable (DNS failure).")
print("TCS requires registration to view job listings.")
print("This scraper attempts tcs.com/careers as a fallback,")
print("but that page only has marketing content, not job listings.")
print("=" * 60)
print()
print("[WARN] ibegin.tcs.com — DNS does not resolve (confirmed March 2026).")
print("[WARN] tcs.com/careers/india/lateral-hiring has no job-level data.")
print("[INFO] TCS gates all job listings behind their iBegin registration portal.")
print("[INFO] Workaround: Use LinkedIn Jobs API or third-party aggregators")
print("       to get TCS India job postings instead.")
print()

tcs_jobs = []
print(f"Total TCS India jobs: {len(tcs_jobs)} (scraper disabled — source unavailable)")
# Out:
# ...
# TCS INDIA JOB SCRAPER
# NOTE: ibegin.tcs.com is no longer reachable (DNS failure).
# TCS requires registration to view job listings.
# This scraper attempts tcs.com/careers as a fallback,
# but that page only has marketing content, not job listings.
# ...
#
# [WARN] ibegin.tcs.com — DNS does not resolve (confirmed March 2026).
# [WARN] tcs.com/careers/india/lateral-hiring has no job-level data.
# [INFO] TCS gates all job listings behind their iBegin registration portal.
# [INFO] Workaround: Use LinkedIn Jobs API or third-party aggregators
#        to get TCS India job postings instead.
#
# Total TCS India jobs: 0 (scraper disabled — source unavailable)

# %%
df_tcs = save_results(tcs_jobs, "TCS", OUTPUT_DIR)
if df_tcs is not None:
    print(f"\nSample jobs:")
    cols = ["title","location_city","seniority_level","business_unit","job_url"]
    cols = [c for c in cols if c in df_tcs.columns]
    print(df_tcs[cols].head(10).to_string())
# Out:
#   [WARN] No jobs found for TCS
