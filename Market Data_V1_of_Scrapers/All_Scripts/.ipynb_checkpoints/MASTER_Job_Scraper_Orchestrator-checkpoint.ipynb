# %%
# ============================================================
# CELL 1: Install Required Dependencies
# ============================================================
# !pip install nbformat nbconvert ipykernel pandas openpyxl -q

# %%
# Discover available kernel names
import subprocess, json
result = subprocess.run(["jupyter", "kernelspec", "list", "--json"], capture_output=True, text=True)
kernels = json.loads(result.stdout)
for name, info in kernels["kernelspecs"].items():
    print(f"{name:40} -> {info['spec']['display_name']}")
# Out:
# python3                                  -> Python 3 (ipykernel)

# %%
# ============================================================
# CELL 2 (FIXED v3): Run All Scraper Notebooks via nbconvert
# Injects a bootstrap cell to fix 'Path not defined' errors
# ============================================================
import os, glob, time
import nbformat
from nbconvert.preprocessors import ExecutePreprocessor, CellExecutionError
from pathlib import Path
from datetime import datetime

SCRIPTS_DIR = Path.home() / "Job_Scrapers" / "All_Scripts"
RUN_LOG = []

# Bootstrap cell to inject at start of every notebook
# Ensures all common imports are available from cell 1 onwards
BOOTSTRAP_CODE = '''# --- AUTO-INJECTED BOOTSTRAP (by orchestrator) ---
import os, re, time, json
import pandas as pd
from pathlib import Path
from datetime import datetime, timedelta
print("[Bootstrap] Common imports loaded")
'''

# All 17 scraper notebooks
NOTEBOOKS = sorted([
    nb for nb in SCRIPTS_DIR.glob("*.ipynb")
    if "MASTER" not in nb.name
])

print(f"Found {len(NOTEBOOKS)} scraper notebooks:")
for nb in NOTEBOOKS:
    print(f"  - {nb.name}")

print("\n" + "="*60)
print(f"Starting execution at {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print("="*60 + "\n")

# FORCE python3 kernel - avoids 'No such kernel' errors
KERNEL = "python3"

for nb_path in NOTEBOOKS:
    start = time.time()
    print(f"[RUNNING] {nb_path.name} ...", end=" ", flush=True)
    try:
        with open(nb_path, encoding="utf-8") as f:
            nb = nbformat.read(f, as_version=4)
        
        # Inject bootstrap cell at position 0
        bootstrap_cell = nbformat.v4.new_code_cell(BOOTSTRAP_CODE)
        nb.cells.insert(0, bootstrap_cell)
        
        ep = ExecutePreprocessor(
            timeout=600,
            kernel_name=KERNEL,
            allow_errors=True  # allow cell-level errors, don't stop the notebook
        )
        ep.preprocess(nb, {"metadata": {"path": str(SCRIPTS_DIR)}})
        
        # Remove the injected bootstrap cell before saving
        nb.cells.pop(0)
        
        # Save the executed notebook back (preserves outputs)
        with open(nb_path, "w", encoding="utf-8") as f:
            nbformat.write(nb, f)
        
        elapsed = round(time.time() - start, 1)
        print(f"DONE ({elapsed}s)")
        RUN_LOG.append({"notebook": nb_path.name, "status": "SUCCESS", "elapsed_s": elapsed})
    except CellExecutionError as e:
        elapsed = round(time.time() - start, 1)
        print(f"FAILED ({elapsed}s) - {str(e)[:120]}")
        RUN_LOG.append({"notebook": nb_path.name, "status": "FAILED", "elapsed_s": elapsed})
    except Exception as e:
        elapsed = round(time.time() - start, 1)
        print(f"ERROR ({elapsed}s) - {str(e)[:120]}")
        RUN_LOG.append({"notebook": nb_path.name, "status": "ERROR", "elapsed_s": elapsed})

print("\n" + "="*60)
print("EXECUTION SUMMARY")
print("="*60)
for log in RUN_LOG:
    icon = "✅" if log["status"] == "SUCCESS" else "❌"
    print(f"{icon} {log['notebook']:<55} {log['status']:<10} {log['elapsed_s']}s")

success_count = sum(1 for l in RUN_LOG if l["status"] == "SUCCESS")
print(f"\nTotal: {success_count}/{len(RUN_LOG)} notebooks completed successfully")
# Out:
# Found 17 scraper notebooks:
#   - Accenture India Job Scraper.ipynb
#   - Apple india Job scrapper.ipynb
#   - Capgemini India Job Scraper.ipynb
#   - Cognizant India Job Scraper.ipynb
#   - Fidelity Investments India Job Scraper.ipynb
#   - Goldman Sachs India Job Scraper.ipynb
#   - Google India Job Scrapper.ipynb
#   - HCL Technologies India Job Scraper.ipynb
#   - IBM India India Job Scraper.ipynb
#   - Infosys India Job Scraper.ipynb
#   - Microsoft India Job Scrapper.ipynb
#   - Morgan Stanley India Job Scraper.ipynb
#   - Novartis India Job scrapper.ipynb
#   - Sanofi India Job Scrapper.ipynb
#   - Syngenta Job Scrapper.ipynb
#   - TCS India Job Scraper.ipynb
#   - Wipro India Job Scraper.ipynb
#
# ============================================================
# Starting execution at 2026-03-09 02:16:54
# ============================================================
#
# [RUNNING] Accenture India Job Scraper.ipynb ... DONE (10.4s)
# [RUNNING] Apple india Job scrapper.ipynb ... DONE (13.3s)
# [RUNNING] Capgemini India Job Scraper.ipynb ...
# /opt/anaconda3/envs/JobAnalyser/lib/python3.14/site-packages/nbformat/__init__.py:96: MissingIDFieldWarning: Cell is missing an id field, this will become a hard error in future nbformat versions. You may want to use `normalize()` on your notebooks before validations (available since nbformat 5.1.4). Previous versions of nbformat are fixing this issue transparently, and will stop doing so in the future.
#   validate(nb)
# DONE (11.2s)
# [RUNNING] Cognizant India Job Scraper.ipynb ... DONE (11.3s)
# [RUNNING] Fidelity Investments India Job Scraper.ipynb ... DONE (11.8s)
# [RUNNING] Goldman Sachs India Job Scraper.ipynb ... DONE (15.7s)
# [RUNNING] Google India Job Scrapper.ipynb ... ERROR (921.7s) - A cell timed out while it was being executed, after 600 seconds.
# The message was: Cell execution timed out.
# Here is a pr
# [RUNNING] HCL Technologies India Job Scraper.ipynb ... DONE (12.0s)
# [RUNNING] IBM India India Job Scraper.ipynb ... DONE (13.2s)
# [RUNNING] Infosys India Job Scraper.ipynb ... DONE (14.7s)
# [RUNNING] Microsoft India Job Scrapper.ipynb ... DONE (13.1s)
# [RUNNING] Morgan Stanley India Job Scraper.ipynb ... DONE (4.0s)
# [RUNNING] Novartis India Job scrapper.ipynb ... DONE (11.4s)
# [RUNNING] Sanofi India Job Scrapper.ipynb ... DONE (10.9s)
# [RUNNING] Syngenta Job Scrapper.ipynb ... DONE (11.2s)
# [RUNNING] TCS India Job Scraper.ipynb ... DONE (16.5s)
# [RUNNING] Wipro India Job Scraper.ipynb ... DONE (15.0s)
#
# ============================================================
# EXECUTION SUMMARY
# ============================================================
# ✅ Accenture India Job Scraper.ipynb                       SUCCESS    10.4s
# ✅ Apple india Job scrapper.ipynb                          SUCCESS    13.3s
# ✅ Capgemini India Job Scraper.ipynb                       SUCCESS    11.2s
# ✅ Cognizant India Job Scraper.ipynb                       SUCCESS    11.3s
# ✅ Fidelity Investments India Job Scraper.ipynb            SUCCESS    11.8s
# ✅ Goldman Sachs India Job Scraper.ipynb                   SUCCESS    15.7s
# ❌ Google India Job Scrapper.ipynb                         ERROR      921.7s
# ✅ HCL Technologies India Job Scraper.ipynb                SUCCESS    12.0s
# ✅ IBM India India Job Scraper.ipynb                       SUCCESS    13.2s
# ✅ Infosys India Job Scraper.ipynb                         SUCCESS    14.7s
# ✅ Microsoft India Job Scrapper.ipynb                      SUCCESS    13.1s
# ✅ Morgan Stanley India Job Scraper.ipynb                  SUCCESS    4.0s
# ✅ Novartis India Job scrapper.ipynb                       SUCCESS    11.4s
# ✅ Sanofi India Job Scrapper.ipynb                         SUCCESS    10.9s
# ✅ Syngenta Job Scrapper.ipynb                             SUCCESS    11.2s
# ✅ TCS India Job Scraper.ipynb                             SUCCESS    16.5s
# ✅ Wipro India Job Scraper.ipynb                           SUCCESS    15.0s
#
# Total: 16/17 notebooks completed successfully

# %%
import pandas as pd
import datetime
from pathlib import Path

# ----- Canonical 24-column schema (matches scraper_utils.py) -----
COLS = [
    "job_id", "title", "company_name", "raw_jd_text",
    "skills_required", "skills_preferred",
    "min_years_experience", "max_years_experience",
    "seniority_level", "location_city", "location_country",
    "work_mode", "employment_type",
    "degree_required", "degree_preferred_field",
    "industry", "salary_min", "salary_max", "salary_currency",
    "date_posted", "is_active",
    "job_url", "business_unit", "source_platform"
]

# ----- Valid controlled-vocab values -----
VALID_SENIORITY  = {"junior", "mid", "senior", "lead"}
VALID_WORK_MODE  = {"onsite", "hybrid", "remote"}
VALID_EMP_TYPE   = {"full-time", "part-time", "contract", "internship"}

# ----- Search all company output folders for CSVs -----
BASE_DIR   = Path.home() / "Job_Scrapers"
MONTH_TAG  = datetime.datetime.now().strftime("%Y_%m")

csv_files  = list(BASE_DIR.rglob(f"*/{MONTH_TAG}/*.csv"))
# Fallback: pick any CSV in Outputs/ subdirs
if not csv_files:
    csv_files = list(BASE_DIR.rglob("*/Outputs/**/*.csv"))
if not csv_files:
    csv_files = list(BASE_DIR.rglob("*.csv"))
    csv_files = [f for f in csv_files if "MASTER" not in f.name]

print(f"Found {len(csv_files)} CSV file(s) to merge:")
for f in csv_files:
    print(f"  {f}")

# ----- Load & tag source file -----
frames = []
for csv_path in csv_files:
    try:
        df = pd.read_csv(csv_path, dtype=str)
        df["_source_file"] = csv_path.name
        frames.append(df)
        print(f"  Loaded {len(df):>5} rows  <- {csv_path.name}")
    except Exception as e:
        print(f"  SKIP {csv_path.name}: {e}")

if not frames:
    print("\nNO CSV DATA FOUND. Run the scrapers first (Cell 2).")
else:
    # ----- Merge -----
    raw = pd.concat(frames, ignore_index=True)

    # ----- Ensure all canonical columns exist -----
    for col in COLS:
        if col not in raw.columns:
            raw[col] = pd.NA

    # ----- Clean job_url: must start with http -----
    if "job_url" in raw.columns:
        raw["job_url"] = raw["job_url"].astype(str).str.strip()
        raw.loc[~raw["job_url"].str.startswith("http", na=False), "job_url"] = pd.NA
        print(f"  job_url populated: {raw['job_url'].notna().sum()} / {len(raw)} rows")

    # ----- Controlled vocab normalisation -----
    raw["seniority_level"]  = raw["seniority_level"].str.lower().where(
        raw["seniority_level"].str.lower().isin(VALID_SENIORITY))
    raw["work_mode"]        = raw["work_mode"].str.lower().where(
        raw["work_mode"].str.lower().isin(VALID_WORK_MODE))
    raw["employment_type"]  = raw["employment_type"].str.lower().where(
        raw["employment_type"].str.lower().isin(VALID_EMP_TYPE))

    # ----- Select & reorder to canonical schema -----
    out = raw[COLS].copy()

    # ----- Save -----
    out_dir = BASE_DIR / "Master_Output"
    out_dir.mkdir(parents=True, exist_ok=True)

    csv_out  = out_dir / f"ALL_JOBS_NORMALIZED_{MONTH_TAG}.csv"
    xlsx_out = out_dir / f"ALL_JOBS_NORMALIZED_{MONTH_TAG}.xlsx"

    out.to_csv(csv_out,   index=False)
    out.to_excel(xlsx_out, index=False)

    print(f"\nDone! {len(out)} total jobs saved.")
    print(f"  CSV  -> {csv_out}")
    print(f"  XLSX -> {xlsx_out}")
    print(f"  Columns ({len(out.columns)}): {list(out.columns)}")
    print(out[["company_name","title","job_url"]].head(10).to_string(index=False))
# Out:
# Found 6 CSV file(s) to merge:
#   /Users/incognito/Job_Scrapers/Apple/Outputs/2026_01/apple_india_jobs_enriched_jan2026.csv
#   /Users/incognito/Job_Scrapers/Apple/Outputs/2026_01/apple_india_jobs_since_jan2026.csv
#   /Users/incognito/Job_Scrapers/Sanofi/Outputs/2026_01/sanofi_india_jobs_history.csv
#   /Users/incognito/Job_Scrapers/Sanofi/Outputs/2026_01/sanofi_india_jobs.csv
#   /Users/incognito/Job_Scrapers/Novartis/Outputs/2026_01/novartis_india_jobs_jan2026_onwards.csv
#   /Users/incognito/Job_Scrapers/Syngenta/Outputs/2026_01/syngenta_jobs_india_since_2026.csv
#   Loaded    86 rows  <- apple_india_jobs_enriched_jan2026.csv
#   Loaded    86 rows  <- apple_india_jobs_since_jan2026.csv
#   Loaded    93 rows  <- sanofi_india_jobs_history.csv
#   Loaded    93 rows  <- sanofi_india_jobs.csv
#   Loaded    87 rows  <- novartis_india_jobs_jan2026_onwards.csv
#   Loaded    31 rows  <- syngenta_jobs_india_since_2026.csv
#
# Raw merged rows: 476
# After dedup by job_id: 212 rows (removed 264 dupes)
# company_name backfilled from path for 212 rows
#
# Saved CSV  -> /Users/incognito/Job_Scrapers/Master_Output/ALL_JOBS_NORMALIZED_2026_03.csv
# Saved XLSX -> /Users/incognito/Job_Scrapers/Master_Output/ALL_JOBS_NORMALIZED_2026_03.xlsx
#
# ============================================================
# FINAL MASTER TABLE: 212 jobs | 21 columns
# ============================================================
#          job_id                                                                     title company_name seniority_level location_city work_mode employment_type  min_years_experience  max_years_experience date_posted  is_active
#             NaN                                                                       NaN        Apple             NaN          None       NaN             NaN                   NaN                   NaN  2026-03-09       True
#     35769542592                                                         Scientific Writer       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN    2026-3-4       True
#     35760108608                                                             Data Engineer       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN    2026-3-3       True
#     34852896640                                             Expert Instructional Designer       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN    2026-2-5       True
#     35745614400                                     Vendor Master Data Management Analyst       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN    2026-3-3       True
#     34636365440                                           Senior Scientific Writer - HEVA       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-1-29       True
#     34194916224                                                             RWE Scientist       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-1-16       True
#     34194916096                                                RWE Project Lead Analytics       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-1-16       True
#     33966746944                                         Senior Medical Information Writer       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN    2026-1-9       True
#     35736014784                                                Scientific Sales Executive       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN    2026-3-3       True
#     35602012608                                                Scientific Sales Executive       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-27       True
#     34827675136              Global Category Buyer External Manufacturing Small Molecules       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN    2026-2-4       True
#     35336069056                                               Talent Optimization Analyst       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-19       True
#     35712276928                          Associate Manager - Global Pricing and Analytics       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN    2026-3-2       True
#     35571528256                                      Project Manager - GTMC North America       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-26       True
#     35566115840                                       Senior Manager - GTMC North America       Sanofi             NaN          None    hybrid             NaN                   NaN                   NaN   2026-2-26       True
#     35617365184                                     Integrations Test Automation Engineer       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-27       True
#     35602012800                                              Quality Assurance Specialist       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-27       True
#     35702516544                                                 Candidate Care Specialist       Sanofi             NaN          None    hybrid             NaN                   NaN                   NaN    2026-3-2       True
#     35630215552                                            Team Lead – Scientific Writing       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-28       True
#     35617366592                                            Team Lead - Business Analytics       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-27       True
#     35617366144                                    Group Lead - Brand & Patient Analytics       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-27       True
#     35617365888                                           Group Lead - Advanced Analytics       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-27       True
#     35480277120                                               FBP Vaccines & partnerships       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-23       True
#     35605938944                                                   DevOps Engineering L2-2       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-27       True
#     35605938816                                                            Team Lead HEVA       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-27       True
#     34098128832                            Project Manager - Supplier Excellence Programs       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-1-13       True
#     34098128064                                          Principal Stats Programmer (VAX)       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-1-13       True
#     34827676096                           R&D Scientific Competitive Intelligence Analyst       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN    2026-2-4       True
#     35602012672                                         Manager – Forecasting & Analytics       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-27       True
#     35571529152                               Project Specialist – Medical Communications       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-26       True
#     35261985856                                                Scientific Sales Executive       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-17       True
#     34827676032                           R&D Scientific Competitive Intelligence Analyst       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN    2026-2-4       True
#     34669952704                                         Associate Project Specialist-HEVA       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-1-30       True
#     35571529536                                          Senior Medical Regulatory Writer       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-26       True
#     35355495680                                Talent Acquisition Partner Talent Services       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-19       True
#     35566115456                                   Accounting Analyst- A2R Cash Accounting       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-26       True
#     35566115328                            Internal Control Global Testing COE Specialist       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-26       True
#     35566115008                            Internal Control Global Testing Senior Analyst       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-26       True
#     35566114816                     Internal Control Global Testing COE Senior Specialist       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-26       True
#     35223745600                        Medical Science Liaison- Rare Blood Disorder- West       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-16       True
#     35292594496                                                Scientific Sales Executive       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-18       True
#     34660573632                                 Patient Experience DevOps Release Manager       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-1-30       True
#     34326244288                                           Digital R&D Senior Scrum Master       Sanofi             NaN          None    hybrid             NaN                   NaN                   NaN   2026-1-20       True
#     35502304064                                                    Manager - CAD services       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-24       True
#     34890734976                                            Team Lead – Scientific Writing       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN    2026-2-6       True
#     35480276928                                                    Manager - CAD services       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-23       True
#     35480276864                                                  Team Lead - CAD services       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-23       True
#     35480276736                                           GEDMS Content System Specialist       Sanofi             NaN          None    remote             NaN                   NaN                   NaN   2026-2-23       True
#     35480276352                                              Junior Drawer - CAD services       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-23       True
#     35474551872                                              Senior Drawer - CAD services       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-23       True
#     34894981888                                                 Pricing & HEOR Lead India       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN    2026-2-6       True
#     33971017856                   Expert, Supply Chain, External Manufacturing Management       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN    2026-1-9       True
#     35369231424                                                 Content Management Expert       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-20       True
#     35364980992             Business System Owner Data Analyst - Salesforce Service Cloud       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-20       True
#     34890735360                                            Expert Scientific Writer- HEVA       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN    2026-2-6       True
#     33877255424        Associate – Evidence Synthesis- Clinical Outcome Assessments (COA)       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN    2026-1-6       True
#     33877255488 Senior Associate – Evidence Synthesis, Clinical Outcome Assessments (COA)       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN    2026-1-6       True
#     34199163008          Senior Scientific Writer (Health Economics and Value Assessment)       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-1-16       True
#     34315502592                                            Expert Scientific Writer- HEVA       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-1-19       True
#     34093873728                                       Manager - HEVA (Evidence Synthesis)       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-1-13       True
#     35331774528                                   Analyst - Customer Facing Effectiveness       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-19       True
#     34971314688                                                       RWE Project Manager       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN    2026-2-8       True
#     35261986304                     Ilearn Operations Support, Processes & Expertise Lead       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-17       True
#     35257697728                                                          Development Lead       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-17       True
#     35257697664                  Qualification and validation specialist, Report issuance       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-17       True
#     34866972224                                              Assistant Manager-Production       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN    2026-2-5       True
#     35129415168    Internal Control Global Testing COE Senior Specialist - Demand to Cash       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-13       True
#     35129414848                               Sales & Customer Engagement Head - Diabetes       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-13       True
#     34402862912                                                          Graphic Designer       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-1-22       True
#     35125226624                                     Team Lead - Data & Process Management       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-13       True
#     35092439232                   Global Environmental Monitoring Expert, Report Issuance       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-12       True
#     35092438976               Global Environmental Monitoring Specialist, Report Issuance       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-12       True
#     35064017920                                      Digital R&D - Veeva Delivery Manager       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-2-11       True
#     34302615424                          Project Manager - Supply Outsourcing Coordinator       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-1-19       True
#     34364660224                           Sr. Accounting Analyst - A2R, Assets Management       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-1-21       True
#     34838625280                              SR. ACCOUNTING ANALYST - A2R - INTER-COMPANY       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN    2026-2-4       True
#     34593913600                         Sr. Accounting Analyst - A2R, Closing & Reporting       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-1-28       True
#     34593913472                             Operations Analyst - A2R, Closing & Reporting       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-1-28       True
#     34862029312                Associate Project Manager - Supply Outsourcing Coordinator       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN    2026-2-5       True
#     34772598720                         Digital R&D Reporting GenAI / GenBI Product Owner       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN    2026-2-2       True
#     34772598400                           Digital R&D Reporting Application Product Owner       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN    2026-2-2       True
#     34767433984                                 Digital R&D Event to Impact Product Owner       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN    2026-2-2       True
#     34762036672                                Digital R&D InSilico CMC Jr. Product Owner       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN    2026-2-2       True
#     34823281344                                                          Graphic Designer       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN    2026-2-4       True
#     34790516352                                              R&D Change Management Expert       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN    2026-2-3       True
#     34757837632                              Digital Functional Expert - People Analytics       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN    2026-2-2       True
#     34559628608                                  Digital Product Owner - People Analytics       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-1-27       True
#     34603432576                                              Workday Operational Services       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-1-28       True
#     34593914112                                                            DOM Specialist       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-1-28       True
#     34369803008                               Associate Project Manager - Medical Affairs       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-1-21       True
#     34302615488                                               Project Specialist - Events       Sanofi             NaN          None    hybrid             NaN                   NaN                   NaN   2026-1-19       True
#     34297552000                                                              Data Analyst       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-1-19       True
#     34093873600             Expert, Quality Operations, External Manufacturing Management       Sanofi             NaN          None       NaN             NaN                   NaN                   NaN   2026-1-13       True
#    REQ-10072953                                                          Forecasting Head     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-03-03       True
#    REQ-10072957      Business Analyst – Marketing Platform Ops (Manager / Senior Manager)     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-03-03       True
#    REQ-10073059                            Senior Manager - Marketing Platform Operations     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-03-03       True
#    REQ-10073061                                        Associate Director - Web Platforms     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-03-03       True
#    REQ-10073056                        Senior Manager – Consent and Preference Management     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-03-03       True
#    REQ-10064625                     Sr. Spec. DDIT OPS ITOT – Service Operational Manager     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-03-03       True
#    REQ-10072914                                                             DAM Librarian     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-03-02       True
#    REQ-10072156                                        Senior Manager - Data Integrations     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-03-02       True
#    REQ-10072159                                     Associate Director, Data Integrations     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-03-02       True
#    REQ-10070504               Associate Director - Clinical Data Landscape Transformation     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-03-02       True
#    REQ-10072905                                                  Data Engineering Manager     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-03-02       True
#    REQ-10072906                                                   Manager Data Governance     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-03-02       True
#    REQ-10072932                                Manager, Payor, Access & Reimbursement I&A     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-03-02       True
#    REQ-10072943                            Sr. Analyst, Payor, Access & Reimbursement I&A     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-03-02       True
#    REQ-10073078                                                            People Partner     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-03-02       True
#    REQ-10072856                                                         Specialist - MS&T     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-03-02       True
#    REQ-10072815                                          Manager MS&T (Validation expert)     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-03-02       True
#    REQ-10072784                                       Specialist - MS&T (Medical Devices)     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-03-02       True
#    REQ-10068761                                              Senior Analyst - Forecasting     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-03-01       True
#    REQ-10069800                                                     Manager - Forecasting     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-03-01       True
#    REQ-10070493                                     Associate Expert Science & Technology     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-03-01       True
#    REQ-10072773                            Assoc. Director SAP Cloud Platform Integration     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-27       True
#    REQ-10065776                                       Associate Clinical Sourcing Manager     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-27       True
#    REQ-10068823                       Category Manager - Medical Affairs, Dev Procurement     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-27       True
#    REQ-10069375                                        Sourcing Manager - Medical Affairs     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-27       True
#    REQ-10072560  Vendor Alliance Lead Associate Director (Cardiac Safety and Diagnostics)     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-27       True
#    REQ-10072568                             Global IT Category- AI Transformation Manager     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-26       True
#    REQ-10065861         ITOT Senior Specialist Manufacturing Services Automation Engineer     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-26       True
#    REQ-10059478                          Executive Director, Human Insights and Analytics     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-26       True
#    REQ-10068945      Associate Director Solution Delivery Manufacturing Execution Systems     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-26       True
#    REQ-10070501                                                           Central Monitor     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-26       True
#    REQ-10072742                                                       eCompliance Manager     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-25       True
#    REQ-10072563                                                 Senior Product Specialist     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-25       True
#    REQ-10072478                     Manager Integrated Evidence Excellence (Coordination)     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-25       True
#    REQ-10072452                                        Manager, Innovation Specialist, AI     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-25       True
#    REQ-10072448                                Manager, Decision Intelligence Solutionist     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-25       True
#    REQ-10072434                                           Manager, AI Business Enablement     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-25       True
#    REQ-10072669                                               AD, IC Design & Diagnostics     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-25       True
#    REQ-10071536                                           Specialist - Quality Operations     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-25       True
#    REQ-10072454         Manager Innovation Lab, Learning & Training Assets Delivery, MAVA     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-25       True
#    REQ-10072671                                                   AD, IC Platform Rollout     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-25       True
#    REQ-10071638                          Digital Finance – Manager (Analytics Operations)     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-25       True
#    REQ-10072653                                                            People Partner     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-25       True
#    REQ-10070942                                         Analyst Clinical Label Management     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-24       True
#    REQ-10072654                                                              Whatfix Lead     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-24       True
#    REQ-10069688                                       Senior Specialist Data Science & AI     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-24       True
#    REQ-10070373                                        Senior Expert Science & Technology     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-24       True
#    REQ-10069689                   Senior Specialist Data Science & AI - Big Data Engineer     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-24       True
#    REQ-10067796                                               Manager, Interactive Design     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-23       True
#    REQ-10067782                                                    Global Project Manager     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-23       True
#    REQ-10072258                                            Manager-RWE Research Analytics     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-23       True
#    REQ-10072373                                          Senior Analyst - Brand Analytics     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-23       True
#    REQ-10072256                                               Senior RWE Research Analyst     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-23       True
#    REQ-10067097                                    Associate Director-Real World Evidence     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-23       True
#    REQ-10070122                                  Sr. Specialist CSOC Onboarding and tools     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-22       True
#    REQ-10071993                               Manager – Solutions Activation & Automation     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-22       True
#    REQ-10069909                                         Manager - Medical Data Enablement     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-22       True
#    REQ-10070491                                                      Lead Central Monitor     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-22       True
#    REQ-10071279                                   Global IT Sourcing Manager- IT Services     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-20       True
#    REQ-10065964                               Manager - Project Management Web Experience     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-20       True
#    REQ-10059805                                    Assoc. Dir. DDIT IES Cloud Engineering     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-20       True
#    REQ-10072359                               Associate Director Economic Modelling (BSI)     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-19       True
#    REQ-10072237                                    Senior Manager – International Finance     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-19       True
#    REQ-10072362   Associate Director, Health Economics Dossier Planning & Execution (BSI)     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-19       True
#    REQ-10072364                                 Director Operations, Value & Access (BSI)     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-19       True
#    REQ-10072363                                          Director, Health Economics (BSI)     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-19       True
#    REQ-10072360             Associate Director Health Economics, Evidence Synthesis (BSI)     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-19       True
#    REQ-10072356            Associate Director Health Economics, Evidence & Insights (BSI)     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-19       True
#    REQ-10071538                                          Senior Analyst - BSI Forecasting     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-18       True
#    REQ-10069227     Expert Science & Technology - (Oligonucleotides/Peptide Therapeutics)     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-18       True
#    REQ-10071628                                              Business Analyst - DAP - PAR     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-12       True
#    REQ-10069056                Territory Business Executive-(Institutional Sales)-Chennai     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-12       True
#    REQ-10071934                                      Territory Business Executive-Chennai     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-12       True
#    REQ-10071020                                   Global IT Sourcing Manager- IT Software     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-06       True
#    REQ-10067192                                       Senior Associate Scientific Writing     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-05       True
#    REQ-10067356                      Analyst, Data Governance, MarTech Product Management     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-03       True
#    REQ-10065856                                                        Product Specialist     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-02       True
#    REQ-10066235                                       Senior Territory Business Executive     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-02-01       True
#    REQ-10068813                                               Manager, Scientific Writing     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-01-30       True
#    REQ-10060901                                           Sr. Specialist - GenAI Engineer     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-01-26       True
#    REQ-10067194                                                Manager Scientific Writing     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-01-22       True
#    REQ-10066394                                  Sr Manager –AI & Innovation -  Reporting     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-01-19       True
#    REQ-10067354      Senior Manager, Web and Campaign Tagging, MarTech Product Management     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-01-13       True
#    REQ-10067571                                                   Senior Business Analyst     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-01-12       True
#    REQ-10064078                                                  Product Manager - Drupal     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-01-12       True
#    REQ-10068583                                                        Product Specialist     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-01-05       True
#    REQ-10063537                                 Info Specialist - Literature Intelligence     Novartis             NaN          None       NaN             NaN                   NaN                   NaN  2026-01-04       True
# 744000112390327                                    Digital Innovation Internal Audit Lead     Syngenta             NaN          None       NaN             NaN                   NaN                   NaN  2026-03-09       True
# 744000112348707                                 Product Specialist - East Commercial Unit     Syngenta             NaN          None       NaN       full-time                   NaN                   NaN  2026-03-09       True
# 744000112268633                           Global Contract Lifecycle Operations Specialist     Syngenta             NaN          None       NaN       full-time                   NaN                   NaN  2026-03-09       True
# 744000112040957                                                               TMD Manager     Syngenta             NaN          None       NaN       full-time                   NaN                   NaN  2026-03-09       True
# 744000111590959                                              Workday Reporting Specialist     Syngenta             NaN          None       NaN       full-time                   NaN                   NaN  2026-03-09       True
# 744000111537175                                                          Business Analyst     Syngenta             NaN          None       NaN       full-time                   NaN                   NaN  2026-03-09       True
# 744000111346108                                                       Business Consultant     Syngenta             NaN          None       NaN       full-time                   NaN                   NaN  2026-03-09       True
# 744000111070877                                                       Business Consultant     Syngenta             NaN          None       NaN       full-time                   NaN                   NaN  2026-03-09       True
# 744000110751016                                               Executive Territory Manager     Syngenta             NaN          None       NaN       full-time                   NaN                   NaN  2026-03-09       True
# 744000110681362                                                           Data Architect      Syngenta             NaN          None       NaN       full-time                   NaN                   NaN  2026-03-09       True
# 744000110680397                                                            Data Engineer      Syngenta             NaN          None       NaN       full-time                   NaN                   NaN  2026-03-09       True
# 744000110373806                                                         AWS AI Infra Lead     Syngenta             NaN          None       NaN       full-time                   NaN                   NaN  2026-03-09       True
# 744000110343733                                                             HSE Executive     Syngenta             NaN          None       NaN       full-time                   NaN                   NaN  2026-03-09       True
# 744000110343053                                              D&A Technical Delivery Lead      Syngenta             NaN          None       NaN       full-time                   NaN                   NaN  2026-03-09       True
# 744000110313745                                                         Backend Developer     Syngenta             NaN          None       NaN       full-time                   NaN                   NaN  2026-03-09       True
# 744000109927225                                                            MLOps Engineer     Syngenta             NaN          None       NaN       full-time                   NaN                   NaN  2026-03-09       True
# 744000109146995                                                               UI Engineer     Syngenta             NaN          None       NaN       full-time                   NaN                   NaN  2026-03-09       True
# 744000108925665                                              Material Master Data Analyst     Syngenta             NaN          None       NaN       full-time                   NaN                   NaN  2026-03-09       True
# 744000108832755                                        Master Data Operations Domain Lead     Syngenta             NaN          None       NaN       full-time                   NaN                   NaN  2026-03-09       True
# 744000108479022                                             Lead Data Solutions Architect     Syngenta             NaN          None       NaN       full-time                   NaN                   NaN  2026-03-09       True
# 744000108135565                                                               AI Engineer     Syngenta             NaN          None       NaN       full-time                   NaN                   NaN  2026-03-09       True
# 744000108132920                                               Executive Territory Manager     Syngenta             NaN          None       NaN       full-time                   NaN                   NaN  2026-03-09       True
# 744000107301603                                        SAP ABAP Techno Functional Analyst     Syngenta             NaN          None       NaN       full-time                   NaN                   NaN  2026-03-09       True
# 744000107301375                SAP Treasury and Risk Management Techno Functional Analyst     Syngenta             NaN          None       NaN       full-time                   NaN                   NaN  2026-03-09       True
# 744000107297196                                       Senior Functional Analyst - SAP TRM     Syngenta             NaN          None       NaN       full-time                   NaN                   NaN  2026-03-09       True
# 744000107015235                                                  Senior Territory Manager     Syngenta             NaN          None       NaN       full-time                   NaN                   NaN  2026-03-09       True
# 744000106266082                                                               Analyst ATR     Syngenta             NaN          None       NaN       full-time                   NaN                   NaN  2026-03-09       True
# 744000106066556                                               Senior Full Stack Developer     Syngenta             NaN          None       NaN       full-time                   NaN                   NaN  2026-03-09       True
# 744000105066418                                               Executive Territory Manager     Syngenta             NaN          None       NaN       full-time                   NaN                   NaN  2026-03-09       True
# 744000104434196                                               Executive Territory Manager     Syngenta             NaN          None       NaN       full-time                   NaN                   NaN  2026-03-09       True
# 744000104167436                                          Enterprise Master Data Architect     Syngenta             NaN          None       NaN       full-time                   NaN                   NaN  2026-03-09       True

# %%
# ============================================================
# CELL 4: Schema Validation & Quality Report
# ============================================================
import pandas as pd

try:
    master
except NameError:
    print("Run Cell 3 first to generate the master DataFrame.")
else:
    print("\n" + "="*60)
    print("SCHEMA VALIDATION REPORT")
    print("="*60)

    # Column completeness
    print(f"\n{'COLUMN':<30} {'NON-NULL':>10} {'NULL%':>8} {'DTYPE':<15}")
    print("-"*65)
    for col in COLS:
        non_null = master[col].notna().sum()
        null_pct  = round((1 - non_null / len(master)) * 100, 1)
        dtype     = str(master[col].dtype)
        flag = " <-- MISSING" if null_pct > 80 else ""
        print(f"{col:<30} {non_null:>10} {null_pct:>7}% {dtype:<15}{flag}")

    print("\n" + "="*60)
    print("CONTROLLED VOCAB DISTRIBUTION")
    print("="*60)
    for col in ["seniority_level", "work_mode", "employment_type"]:
        print(f"\n{col}:")
        print(master[col].value_counts(dropna=False).to_string())

    print("\n" + "="*60)
    print("JOBS PER COMPANY")
    print("="*60)
    print(master["company_name"].value_counts().to_string())

    print("\n" + "="*60)
    print("ACTIVE vs INACTIVE")
    print("="*60)
    print(master["is_active"].value_counts().to_string())

    print("\n" + "="*60)
    print(f"TOTAL: {len(master)} unique jobs across {master['company_name'].nunique()} companies")
    print(f"Output: ~/Job_Scrapers/Master_Output/")
    print("="*60)
# Out:
# ============================================================
# SCHEMA VALIDATION REPORT
# ============================================================
#
# COLUMN                           NON-NULL    NULL% DTYPE
# -----------------------------------------------------------------
# job_id                                211     0.5% str
# title                                 211     0.5% str
# company_name                          212     0.0% object
# raw_jd_text                             0   100.0% object          <-- MISSING
# skills_required                       212     0.0% object
# skills_preferred                      212     0.0% object
# min_years_experience                    0   100.0% float64         <-- MISSING
# max_years_experience                    0   100.0% float64         <-- MISSING
# seniority_level                         0   100.0% str             <-- MISSING
# location_city                           0   100.0% object          <-- MISSING
# location_country                      212     0.0% object
# work_mode                               5    97.6% str             <-- MISSING
# employment_type                        30    85.8% str             <-- MISSING
# degree_required                         0   100.0% object          <-- MISSING
# degree_preferred_field                  0   100.0% object          <-- MISSING
# industry                               30    85.8% str             <-- MISSING
# salary_min                              0   100.0% float64         <-- MISSING
# salary_max                              0   100.0% float64         <-- MISSING
# salary_currency                       212     0.0% object
# date_posted                           212     0.0% str
# is_active                             212     0.0% bool
#
# ============================================================
# CONTROLLED VOCAB DISTRIBUTION
# ============================================================
#
# seniority_level:
# seniority_level
# NaN    212
#
# work_mode:
# work_mode
# NaN       207
# hybrid      4
# remote      1
#
# employment_type:
# employment_type
# NaN          182
# full-time     30
#
# ============================================================
# JOBS PER COMPANY
# ============================================================
# company_name
# Sanofi      93
# Novartis    87
# Syngenta    31
# Apple        1
#
# ============================================================
# ACTIVE vs INACTIVE
# ============================================================
# is_active
# True    212
#
# ============================================================
# TOTAL: 212 unique jobs across 4 companies
# Output: ~/Job_Scrapers/Master_Output/
# ============================================================
