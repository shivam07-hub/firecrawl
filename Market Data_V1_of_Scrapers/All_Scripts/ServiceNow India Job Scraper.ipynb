# %% [markdown]
# # ServiceNow India Job Scraper
# ## India Jobs Scraper (v2.1 - March 2026)
# **Source:** api.smartrecruiters.com/ServiceNow
#
# **ATS Detection:** Automatic API + Selenium fallback

# %%
# !pip install selenium webdriver-manager pandas openpyxl requests beautifulsoup4 lxml playwright -q
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import sys, time, random, re
from pathlib import Path

# Add scripts dir to path so we can import scraper_utils
SCRIPTS_DIR = Path.home() / "Job_Scrapers" / "All_Scripts"
sys.path.insert(0, str(SCRIPTS_DIR))

from scraper_utils import *
import requests
from bs4 import BeautifulSoup
from datetime import datetime, timedelta

# ── LOCATION CONFIG ──────────────────────────────────────────────────────────
# Change to "" to scrape globally (all countries).
# The matching pipeline's pre-filter handles India-specific narrowing.
# Set to "India" here only if you want to reduce volume at scrape time.
LOCATION_FILTER = ""
COUNTRY_CODE   = ""  # e.g. "in" for SmartRecruiters country= param; "" = all
# ─────────────────────────────────────────────────────────────────────────────

print("Imports loaded. Date:", datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print(f"Location filter: '{LOCATION_FILTER}' (empty = broad/global scraping)")
# Out:
# scraper_utils.py loaded successfully
# Schema: 25 columns
# Skills DB: 79 skills
# Imports loaded. Date: 2026-04-01 00:38:16
# Location filter: '' (empty = broad/global scraping)

# %%
COMPANY = "ServiceNow"
OUTPUT_DIR = get_output_dir(COMPANY)
print(f"Output directory: {OUTPUT_DIR}")
# Out:
# Output directory: /Users/incognito/Job_Scrapers/All_CSV_Outputs/ServiceNow/Outputs/2026_04_01

# %%
print("=" * 60)
print("SERVICENOW INDIA JOB SCRAPER")
print("ATS: SmartRecruiters (careers.smartrecruiters.com/servicenow)")
print("=" * 60)

servicenow_jobs = scrape_smartrecruiters(
    company_id="ServiceNow",
    company_name="ServiceNow",
    industry="Technology / IT Service Management / SaaS",
    country=COUNTRY_CODE,
    max_jobs=500
)
# Out:
# ============================================================
# SERVICENOW INDIA JOB SCRAPER
# ATS: SmartRecruiters (careers.smartrecruiters.com/servicenow)
# ============================================================
#   Scraping ServiceNow via SmartRecruiters API (country='' — broad/global)
#   Page offset=0: 100 jobs
#   Page offset=100: 100 jobs
#   Page offset=200: 100 jobs
#   Page offset=300: 100 jobs
#   Page offset=400: 100 jobs
#   Total ServiceNow India jobs: 500

# %%
df_servicenow = save_results(servicenow_jobs, "ServiceNow", OUTPUT_DIR)
if df_servicenow is not None:
    print(f"\nSample jobs:")
    cols = ["title","location_city","seniority_level","business_unit","job_url"]
    cols = [c for c in cols if c in df_servicenow.columns]
    print(df_servicenow[cols].head(10).to_string())
# Out:
#   [OK] Saved 455 jobs -> ServiceNow_jobs_2026-04-01.csv
#        Seniority: {'lead': 239, 'junior': 192, 'mid': 15, 'senior': 9}
#        Work mode: {'remote': 443, 'hybrid': 12}
#        Has JD text: 455/455
#        Has job URL: 455/455
#        Has business unit: 415/455
#
# Sample jobs:
#                                                                        title  location_city seniority_level                         business_unit                                                      job_url
# 0                                                 Senior Solution Consultant         Munich            lead                                 Sales  https://jobs.smartrecruiters.com/ServiceNow/744000117970089
# 1                                              Advisory Solution Consultant          Munich          junior                                 Sales  https://jobs.smartrecruiters.com/ServiceNow/744000117969419
# 2                                               AI Product Portfolio Manager        Addison            lead  Marketing, Communications, and Brand  https://jobs.smartrecruiters.com/ServiceNow/744000117964557
# 3                                               Advisory Solution Consultant     Glattbrugg            lead                                 Sales  https://jobs.smartrecruiters.com/ServiceNow/744000117952354
# 4                                   VP, GTM Strategic Leader (CHRO/CFO/COO)     Santa Clara          junior                                 Sales  https://jobs.smartrecruiters.com/ServiceNow/744000117952270
# 5                                        Business Development Representative         Sydney          junior  Marketing, Communications, and Brand  https://jobs.smartrecruiters.com/ServiceNow/744000117948969
# 6  Federal DOD/Intel Senior Solution Sales Executive- Identity and Security      Washington          junior                                 Sales  https://jobs.smartrecruiters.com/ServiceNow/744000117943384
# 7                                         Resell Partner Manager - Amsterdam      Amsterdam            lead                                 Sales  https://jobs.smartrecruiters.com/ServiceNow/744000117915922
# 8                         Senior Manager, Strategy & Operations — Moveworks   Mountain View            lead                     Customer Outcomes  https://jobs.smartrecruiters.com/ServiceNow/744000117883727
# 9                            Senior Manager, Solution Consulting - Moveworks         Munich            lead                                 Sales  https://jobs.smartrecruiters.com/ServiceNow/744000117872247
