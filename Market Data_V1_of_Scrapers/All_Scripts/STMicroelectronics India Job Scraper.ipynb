# %% [markdown]
# # STMicroelectronics India Job Scraper
# ## India Jobs Scraper (v2.1 - March 2026)
# **Source:** stmicroelectronics.eightfold.ai/careers
#
# **ATS:** Eightfold AI

# %%
# !pip install selenium webdriver-manager pandas openpyxl requests beautifulsoup4 lxml -q
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import sys, time, random
from pathlib import Path
SCRIPTS_DIR = Path.home() / 'Job_Scrapers' / 'All_Scripts'
sys.path.insert(0, str(SCRIPTS_DIR))
from scraper_utils import *
from datetime import datetime
LOCATION_FILTER = ''
print('Imports loaded. Date:', datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# scraper_utils.py loaded successfully
# Schema: 25 columns
# Skills DB: 79 skills
# Imports loaded. Date: 2026-04-01 00:17:47

# %%
COMPANY = 'STMicroelectronics'
OUTPUT_DIR = get_output_dir(COMPANY)
print(f'Output directory: {OUTPUT_DIR}')
# Out:
# Output directory: /Users/incognito/Job_Scrapers/All_CSV_Outputs/STMicroelectronics/Outputs/2026_04_01

# %%
print('=' * 60)
print('STMICROELECTRONICS INDIA JOB SCRAPER')
print('ATS: Eightfold AI (stmicroelectronics.eightfold.ai)')
print('=' * 60)

st_jobs = scrape_eightfold(
    domain='stmicroelectronics.eightfold.ai',
    company_name='STMicroelectronics',
    industry='Semiconductor / Electronics',
    location_filter=LOCATION_FILTER,
    max_jobs=500
)
# Out:
# ...
# STMICROELECTRONICS INDIA JOB SCRAPER
# ATS: Eightfold AI (stmicroelectronics.eightfold.ai)
# ...
#   Scraping STMicroelectronics via Eightfold API: stmicroelectronics.eightfold.ai (global)
#   [ERROR] HTTP 404
#   Total STMicroelectronics India jobs: 0

# %%
df_st = save_results(st_jobs, 'STMicroelectronics', OUTPUT_DIR)
if df_st is not None:
    cols = ['title','location_city','seniority_level','business_unit','job_url']
    cols = [c for c in cols if c in df_st.columns]
    print(df_st[cols].head(10).to_string())
# Out:
#   [WARN] No jobs found for STMicroelectronics
