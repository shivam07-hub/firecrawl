# %% [markdown]
# # Airbus India Job Scraper
# ## India Jobs Scraper (v2.1 - March 2026)
# **Source:** ag.wd3.myworkdayjobs.com/Airbus
#
# **ATS:** Workday

# %%
# !pip install selenium webdriver-manager pandas openpyxl requests beautifulsoup4 lxml -q

# %%
import sys, time, random
from pathlib import Path
SCRIPTS_DIR = Path.home() / 'Job_Scrapers' / 'All_Scripts'
sys.path.insert(0, str(SCRIPTS_DIR))
from scraper_utils import *
from datetime import datetime
LOCATION_FILTER = ''
print('Imports loaded. Date:', datetime.now().strftime('%Y-%m-%d %H:%M:%S'))

# %%
COMPANY = 'Airbus'
OUTPUT_DIR = get_output_dir(COMPANY)
print(f'Output directory: {OUTPUT_DIR}')

# %%
print('=' * 60)
print('AIRBUS INDIA JOB SCRAPER')
print('ATS: Workday (ag.wd3.myworkdayjobs.com/Airbus)')
print('=' * 60)

airbus_jobs = scrape_workday(
    tenant='ag',
    instance='wd3',
    career_site='Airbus',
    company_name='Airbus',
    industry='Aerospace & Defense',
    location_filter=LOCATION_FILTER,
    max_jobs=500
)

# %%
df_airbus = save_results(airbus_jobs, 'Airbus', OUTPUT_DIR)
if df_airbus is not None:
    cols = ['title','location_city','seniority_level','business_unit','job_url']
    cols = [c for c in cols if c in df_airbus.columns]
    print(df_airbus[cols].head(10).to_string())
