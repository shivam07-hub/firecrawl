# %% [markdown]
# # CNHI India IT Job Scraper
# **ATS:** SAP SuccessFactors / Jobs2Web (join.cnh.com)
#
# **Note:** This notebook is a stub. The actual scraper runs via `run_cnhi.py`
# which is invoked by MASTER_Job_Scraper_Orchestrator_v2.py as a companion script.

# %%
import subprocess, sys
from pathlib import Path
script = Path.home() / 'Job_Scrapers' / 'All_Scripts' / 'run_cnhi.py'
result = subprocess.run([sys.executable, str(script)], capture_output=False)
sys.exit(result.returncode)
