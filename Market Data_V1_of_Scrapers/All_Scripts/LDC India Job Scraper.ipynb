# %% [markdown]
# # LDC (Louis Dreyfus Company) India Job Scraper
# ## India Jobs Scraper (v2.1 - March 2026)
# **Source:** SmartRecruiters — company ID: LouisDreyfusCompany
#
# **ATS:** SmartRecruiters

# %%
# !pip install selenium webdriver-manager pandas openpyxl requests beautifulsoup4 lxml -q
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import sys, time, random
from pathlib import Path
SCRIPTS_DIR = Path.home() / 'Job_Scrapers' / 'All_Scripts'
sys.path.insert(0, str(SCRIPTS_DIR))
from scraper_utils import *
from datetime import datetime
COUNTRY_CODE = ''
print('Imports loaded. Date:', datetime.now().strftime('%Y-%m-%d %H:%M:%S'))
# Out:
# scraper_utils.py loaded successfully
# Schema: 25 columns
# Skills DB: 79 skills
# Imports loaded. Date: 2026-03-31 23:38:59

# %%
COMPANY = 'LDC'
OUTPUT_DIR = get_output_dir(COMPANY)
print(f'Output directory: {OUTPUT_DIR}')
# Out:
# Output directory: /Users/incognito/Job_Scrapers/All_CSV_Outputs/LDC/Outputs/2026_03_31

# %%
print('=' * 60)
print('LDC (LOUIS DREYFUS COMPANY) INDIA JOB SCRAPER')
print('ATS: SmartRecruiters (company: LouisDreyfusCompany)')
print('=' * 60)

ldc_jobs = scrape_smartrecruiters(
    company_id='LouisDreyfusCompany',
    company_name='Louis Dreyfus Company',
    industry='Commodities / Agri-business',
    country=COUNTRY_CODE,
    max_jobs=500
)
# Out:
# ...
# LDC (LOUIS DREYFUS COMPANY) INDIA JOB SCRAPER
# ATS: SmartRecruiters (company: LouisDreyfusCompany)
# ...
#   Scraping Louis Dreyfus Company via SmartRecruiters API (country='' — broad/global)
#   Page offset=0: 100 jobs
#   Page offset=100: 100 jobs
#   Page offset=200: 100 jobs
#   Page offset=300: 100 jobs
#   Page offset=400: 24 jobs
#   Total Louis Dreyfus Company India jobs: 424

# %%
df_ldc = save_results(ldc_jobs, 'LDC', OUTPUT_DIR)
if df_ldc is not None:
    cols = ['title','location_city','seniority_level','business_unit','job_url']
    cols = [c for c in cols if c in df_ldc.columns]
    print(df_ldc[cols].head(10).to_string())
# Out:
#   [OK] Saved 414 jobs -> LDC_jobs_2026-03-31.csv
#        Seniority: {'junior': 292, 'mid': 98, 'senior': 12, 'lead': 12}
#        Work mode: {'onsite': 346, 'hybrid': 58, 'remote': 10}
#        Has JD text: 413/414
#        Has job URL: 414/414
#        Has business unit: 0/414
#                                                  title location_city seniority_level business_unit                                                               job_url
# 0         ESTAGIARIO Planejamento Logística Arco Norte     PARANAGUA             mid                https://jobs.smartrecruiters.com/LouisDreyfusCompany/744000117958676
# 1   Analista de Gestión de Mantenimiento de Activos Sr       Rosario          junior                https://jobs.smartrecruiters.com/LouisDreyfusCompany/744000117955717
# 2                                            Ensacador        MATIPO             mid                https://jobs.smartrecruiters.com/LouisDreyfusCompany/744000117885150
# ...
